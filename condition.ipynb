# %%
x=int(input("enter the age:"))
if x<=18:
    print("elegible for vot")
# Out:
# enter the age: 18
# elegible for vot

# %% [markdown]
# # if_else

# %%
Addhar_card=str(input("have you Addhar card?:"))
if Addhar_card.lower()=="yes":
 print("indian")
# Out:
# have you Addhar card?: yes
# indian

# %%
Addhar_card = input("Have you Aadhaar card?: ")
if Addhar_card.lower() == "yes":
    print("you are Indian")
else:
    print("not an Indian")
# Out:
# Have you Aadhaar card?:  yes
# you are Indian

# %%
name=input("enter name:")
if name=="preetiranjan":
    print("good morning")
else:
    print("you are unknown")
# Out:
# enter name: preetiranjan
# good morning

# %% [markdown]
# # if-elif-else

# %%
x=int(input("enter x value:"))
if x<10:
    print("first")
elif x<40:
    print("last")
else:
    print("fail")
# Out:
# enter x value: 50
# fail

# %%
G=int(input("enter G value:"))
if G>=90:
        print("Grade A")
elif G>=60:
        print("Grade B")
elif G>=40:
        print("Grade c")
else:
        print("Grade F")
# Out:
# enter G value: 60
# Grade B

# %%
n=int(input("enter a number:"))    # Doubt
# if ((2*n)%2==0):
#         print("even")
if (2*n)/2==n:
        print("even")
else:
    print("odd")
# Out:
# enter a number: 11
# even

# %%
Name=input("enter your name:")
if Name=="Mohan":
        print("chief minister of odisha")
else:
        print("good morning",Name,"you are not a chief minister")
# Out:
# enter your name: Prabhas
# good morning Prabhas you are not a chief minister

# %%
st=["ranjan","kalia","jaga"]
if "jaga" in st:
        print("He is a devloper")
if "jitu" not in st:
        print("He is missing")
# Out:
# He is a devloper
# He is missing

# %%
b=int(input())
if (b>=0):
    print(b,"positive number")
else:
    print(b,"is negative number")
# Out:
#  -23
# -23 is negative number

# %%
x=int(input())
y="(GIFT)"
if((x>60)or(x>90)):
    print("He is pass and 'A' Grade")
elif((x>30)and(x<60)):
    print("improve your study")
else:
    print("you are fail and give rs-500,for improvement",y)
# Out:
#  23
# you are fail and give rs-500,for improvement (GIFT)

# %%
if 1 is 3:
    print("what is this")
elif 1>3:
    print("this is not correct")
else:
    print("yes")
# Out:
# yes
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\91934\AppData\Local\Temp\ipykernel_18760\546759653.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if 1 is 3:

# %%
mark=int(float(input("enter mark")))
if(mark>85 and mark<=100):
    print(mark,"A grade")
elif(mark<=85 and mark>75):
    print(mark,"B grade")
elif(mark<=75 and mark>65):
    print(mark,"C grade")
elif(mark<=65 and mark>55):
    print(mark,"D grade")
elif(mark<=55 and mark>45):
    print(mark,"E grade")
else:
    print(mark,"FAIL")
# Out:
# enter mark 75
# 75 C grade

# %%
n1=int(input("enter num"))
n2=int(input("enter second num"))
if n1>n2:
       print(n1,"is biggest")
else:
        print(n2,"is biggest")
# Out:
# enter num 67
# enter second num 78
# 78 is biggest

# %% [markdown]
# #  Nested if

# %%
a=45
if a>=0:
    if a == 0:
        print("not a zero")
    else:
        print("negative")
else:
    print("positive number")
# Out:
# negative

# %%
amount=50000
pin=7560
if(int(input('enter your pin'))==7560):
    with_draw=int(input('with draw amount:'))
    if (with_draw<=amount):
        print(with_draw,'succcesfully transaction complite')
    else:
        print(with_draw,'not sufficient funds in your account')
else:
    print('invalid pin number')
# Out:
# enter your pin 7560
# with draw amount: 50000
# 50000 succcesfully transaction complite
