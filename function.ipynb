# %%
def even_odd(a): #one argument
    # a=int(input("enter a value"))
    if a%2==0:
        print("even")
    else:
        print("odd")

# %%
even_odd(2)
# Out:
# even

# %%
def sum_is_even_odd(a,b): 
     # a=int(input("enter a value"))
     # b=int(input("enter a value"))
     s=a+b
     if s%2==0:
        print("even")
     else:
        print("odd")
     return s

# %%
sum_is_even_odd(2,3)
# Out:
# odd
# 5

# %%
def fact():
    n=int(input("enter n"))
    if n<0:
        print("no result")
    elif n==0:
        print("factorial is 1")
    elif n>=1:
        fact=1
    for i in range(1,n+1):
        fact*=i
    print("The factorial is:",fact)

# %%
fact()
# Out:
# enter n 5
# The factorial is: 120

# %%
def mul_two_no(a,b):
    c=a*b
    print("multiplication of{}&{} is:".format(a,b),c)

# %%
mul_two_no(5,6)
# Out:
# multiplication of5&6 is: 30

# %%
def mul_two_no(a,b=5):
    a=int(input("enter number for a"))
    b=int(input("enter number for b"))
    c=a*b
    print("multiplication of{}&{} is:".format(a,b),c)

# %%
mul_two_no(5)
# Out:
# enter number for a 5
# enter number for b 5
# multiplication of5&5 is: 25

# %%
mul_two_no(5,7)
# Out:
# enter number for a 89
# enter number for b 90
# multiplication of89&90 is: 8010

# %%
def mul_two_no(a,b=5):
    # a=int(input("enter number for a"))
    # b=int(input("enter number for b"))
    c=a*b
    print("multiplication of{}&{} is:".format(a,b),c)

# %%
mul_two_no(5)
# Out:
# multiplication of5&5 is: 25

# %%
def greet(**kwargs):
    if kwargs:
        print("hello {},{}".format(kwargs["name"],kwargs["msg"]))
greet(name="good",msg="Good morning")
# Out:
# hello good,Good morning

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 greet(name="good",msg="Good morning")
#
# TypeError: greet() got an unexpected keyword argument 'name'

# %%
def greet(*kwargs):
    for i in kwargs:
        print("hello {}".format(kwargs))

# %%
greet(5,6)
# Out:
# hello (5, 6)
# hello (5, 6)

# %%
a=int(input("enter a"))
b=int(input("enter b"))
def addition(a,b):
    return a+b
    
    print("addition {}&{}is{}".format(a,b,addition()))
# Out:
# enter a 6
# enter b 9

# %%
a=int(input("enter a"))
b=int(input("enter b"))
def addition(a,b):
    return a+b
    
    print("the addition of {}&{}is{}".format(a,b,addition()))
# Out:
# enter a 7
# enter b 8

# %%
a = int(input("Enter 1st number: "))
b = int(input("Enter 2nd number: "))

def addition():
    return a + b

def subtraction():
    return a - b

def multiplication():
    return a * b

def division():
    return a / b

def modulo():
    return a % b

d=int(input("choose one"))

if d==1:
    print("The addition of {} & {} is {}".format(a,b,addition()))
if d==2:
    print("The subtraction of {} & {} is {}".format(a,b,subtraction()))
if d==3:
    print("The multiplication of {} & {} is {}".format(a,b,multiplication()))
if d==4:
    print("The division of {} & {} is {}".format(a,b,division()))
# Out:
# Enter 1st number:  8
# Enter 2nd number:  9
# choose one 1
# The addition of 8 & 9 is 17

# %%
import math

def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error! Division by zero."
    else:
        return x / y

def sine(x):
    return math.sin(math.radians(x))

def cosine(x):
    return math.cos(math.radians(x))

def tangent(x):
    return math.tan(math.radians(x))

def logarithm(x, base=10):
    if x <= 0:
        return "Error! Logarithm of non-positive number."
    else:
        return math.log(x, base)

def exponential(x):
    return math.exp(x)

def power(x, y):
    return math.pow(x, y)

def square_root(x):
    if x < 0:
        return "Error! Square root of negative number."
    else:
        return math.sqrt(x)

def main():
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Sine")
    print("6. Cosine")
    print("7. Tangent")
    print("8. Logarithm")
    print("9. Exponential")
    print("10. Power")
    print("11. Square Root")

    while True:
        choice = input("Enter choice (1-11): ")

        if choice in ('1', '2', '3', '4', '10'):
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))

            if choice == '1':
                print(f"{num1} + {num2} = {add(num1, num2)}")

            elif choice == '2':
                print(f"{num1} - {num2} = {subtract(num1, num2)}")

            elif choice == '3':
                print(f"{num1} * {num2} = {multiply(num1, num2)}")

            elif choice == '4':
                print(f"{num1} / {num2} = {divide(num1, num2)}")

            elif choice == '10':
                print(f"{num1} ^ {num2} = {power(num1, num2)}")

        elif choice in ('5', '6', '7', '8', '9', '11'):
            num = float(input("Enter number: "))

            if choice == '5':
                print(f"sin({num}) = {sine(num)}")

            elif choice == '6':
                print(f"cos({num}) = {cosine(num)}")

            elif choice == '7':
                print(f"tan({num}) = {tangent(num)}")

            elif choice == '8':
                base = float(input("Enter base (default is 10): ") or 10)
                print(f"log({num}, {base}) = {logarithm(num, base)}")

            elif choice == '9':
                print(f"exp({num}) = {exponential(num)}")

            elif choice == '11':
                print(f"sqrt({num}) = {square_root(num)}")

        else:
            print("Invalid Input")

        next_calculation = input("Do you want to perform another calculation? (yes/no): ")
        if next_calculation.lower() != 'yes':
            break

if __name__ == "__main__":
    main()
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. Logarithm
# 9. Exponential
# 10. Power
# 11. Square Root
# Enter choice (1-11):  1
# Enter first number:  45
# Enter second number:  67
# 45.0 + 67.0 = 112.0
# Do you want to perform another calculation? (yes/no):  no

# %% [markdown]
# # create a function to calculate compound intrest

# %%
#amount = principal * (1 + rate / times_compounded) ** (times_compounded * years)
    #return amount

p=float(input("enter principal amount:"))
r=float(input("rate of intrest:"))
t=float(input("time duration for compound intrest:"))
y=float(input("years:"))
def compound_int():
    amount=p*(1+r/t)**(t*y)
    return amount
print("principal={},rate{},time{},year{},the compound intrest of amount is{}".format(p,r,t,y,compound_int()))
# Out:
# enter principal amount: 1000
# rate of intrest: 8
# time duration for compound intrest: 4
# years: 3
# principal=1000.0,rate8.0,time4.0,year3.0,the compound intrest of amount is531441000.0

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## write a program
# 1.enter 10 students name using function
# 2.loop
# 3.print
# 4.store a list

# %%
def student_database():
    a=input("enter the name:")
    return a
student_list=[]
t=1
while t<=10:
        t=t+1
        a="{}".format(student_database())
        student_list.append(a)
print(student_list)
# Out:
# enter the name: fsf
# enter the name: fhsfh
# enter the name: fnesf
# enter the name: fnsfjs
# enter the name: sffs
# enter the name: f;nfn
# enter the name: fnsjkf
# enter the name: fjbj
# enter the name: fsf
# enter the name: fbsfbk
# ['fsf', 'fhsfh', 'fnesf', 'fnsfjs', 'sffs', 'f;nfn', 'fnsjkf', 'fjbj', 'fsf', 'fbsfbk']

# %% [markdown]
# # Built in functions

# %%
n=-500
abs(n)
# Out:
# 500

# %%
divmod(2,10)
# Out:
# (0, 2)

# %%
def get_sum(ist):
    sum=0
    for num in ist:
        sum+=num
    return sum
    get_sum([1,2,3,4])

# %%
get_sum([1,2,3,4])
# Out:
# 10

# %%
def primenum():
    count=0
    if num%2==0:
    count=count+1
