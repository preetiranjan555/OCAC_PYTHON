# %%
A=[83268,63,844868,312,0,84020,8050,578,35]
type(A)
# Out:
# list

# %%
c=list(set(A))
print(c)
# Out:
# [0, 578, 35, 83268, 844868, 8050, 84020, 312, 63]

# %%
A = set([83268,63,844868,312,0,84020,8050,578,35])

# %%
A
# Out:
# {0, 35, 63, 312, 578, 8050, 83268, 84020, 844868}

# %%
A=[83268,63,844868,312,0,84020,8050,578,35]
b=set(A)
b
# Out:
# {0, 35, 63, 312, 578, 8050, 83268, 84020, 844868}

# %%
k=set([555,0,557,87,399,799,56,12,9])
k
# Out:
# {0, 9, 12, 56, 87, 399, 555, 557, 799}

# %%
t=set(67,45,992,23,3,98)
t.add(1)
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 t=set(67,45,992,23,3,98)
#       2 t.add(1)
#       3 t
#
# TypeError: set expected at most 1 argument, got 6

# %%
k=set(t)
k
# Out:
# {3, 23, 45, 67, 98, 992}

# %%
k1=tuple(k)
print(k)
# Out:
# {992, 98, 3, 67, 45, 23}

# %%
a={1,43,41,32}
b=a   #shalow copy
print(b)
# Out:
# {32, 1, 43, 41}

# %%
b=a.copy() #deep copy

# %%
print(b)
# Out:
# {32, 1, 43, 41}

# %%
s1={1,3,5,3,2,7}
print(s1)
# Out:
# {1, 2, 3, 5, 7}

# %%
s5={'a:sun','b:mon','c:tues'}
s5
# Out:
# {'a:sun', 'b:mon', 'c:tues'}

# %%
s=list(s1)
s
# Out:
# [1, 2, 3, 5, 7]

# %%
type(s)
# Out:
# list

# %%
t=tuple(s1)
t
# Out:
# (1, 2, 3, 5, 7)

# %%
type(t)
# Out:
# tuple

# %%
k=set()
k=set(range(3,20,3))
k
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 k=set()
# ----> 2 k=set(range(3,20,3))
#       3 k
#
# TypeError: 'set' object is not callable

# %%
s=set()
s
# Out:
# set()

# %%
b=set()
b.add(67)
b.add(61)
b.add(66)
b.add(63)
b.add(62)
b
# Out:
# {61, 62, 63, 66, 67}

# %%
b.update({23,31,12})
print(b)
# Out:
# {66, 67, 12, 23, 31, 61, 62, 63}

# %%
c=b.copy()
c
# Out:
# {12, 23, 31, 61, 62, 63, 66, 67}

# %%
c.discard(12)
c
# Out:
# {23, 31, 61, 62, 63, 66, 67}

# %%
c.discard(10) #no error
c
# Out:
# {23, 31, 61, 62, 63, 66, 67}

# %%
c.remove(62)
c
# Out:
# {23, 31, 61, 63, 66, 67}

# %%
c.remove(10) #error show 
c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 c.remove(10)
#       2 c
#
# KeyError: 10

# %%
set1={89,34,32,45}
set2={56,67,87,54}
print(set1|set2)
# Out:
# {32, 34, 67, 45, 54, 87, 56, 89}

# %%
print(set1.union(set2))
# Out:
# {32, 34, 67, 45, 54, 87, 56, 89}

# %%
set3={89,34,32,45}
set4={56,67,87,54}
print(set3 & set4)
print(set3.intersection(set4)) #doubt
print(set1|set2)
# Out:
# set()
# set()
# {32, 34, 67, 45, 54, 87, 56, 89}

# %%
a={87,67,54,90}
b={43,12,54,97}
print(a-b)
print(b-a)
print(a.difference(b))
a.difference_update(b)
print(a)
# Out:
# {90, 67, 87}
# {97, 43, 12}
# {90, 67, 87}
# {90, 67, 87}

# %%
c={7,6,5,9,3}
d={1,2,4,9,5}
print(c.symmetric_difference(d))
# Out:
# {1, 2, 3, 4, 6, 7}

# %%
a={87,67,54,90}
b={43,12,54,97,67,56}
a.issubset(b)
# Out:
# False

# %%
a={87,67,54,90}
b={87,67,54,90,45,67}
print(a.issubset(b))
print(b.issuperset(a))
# Out:
# True
# True

# %%
d={}
d
# Out:
# {}

# %%
type(d)
# Out:
# dict

# %%
d={"student":"MCA","Course":"python_intership","fees":7000,"place":"OCAC"}
d
# Out:
# {'student': 'MCA', 'Course': 'python_intership', 'fees': 7000, 'place': 'OCAC'}

# %%
type(d)
# Out:
# dict

# %%
d["student"]
# Out:
# 'MCA'

# %%
d["MCA"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 d["MCA"]
#
# KeyError: 'MCA'

# %%
d["fees"]
# Out:
# 7000

# %%
d.keys()
# Out:
# dict_keys(['student', 'Course', 'fees', 'place'])

# %%
d.values()
# Out:
# dict_values(['MCA', 'python_intership', 7000, 'OCAC'])

# %%
d={"student":"MCA","Course":"python_intership","fees":7000,"place":"OCAC"}
d.items()
# Out:
# dict_items([('student', 'MCA'), ('Course', 'python_intership'), ('fees', 7000), ('place', 'OCAC')])

# %%
d["fees"]="8000"
d
# Out:
# {'student': 'MCA',
#  'Course': 'python_intership',
#  'fees': '8000',
#  'place': 'OCAC'}

# %%
a={"bike1":{"ninja":1991},"bike2":{"boolet":1998},"bike3":{"hero":1986}}
a
# Out:
# {'bike1': {'ninja': 1991}, 'bike2': {'boolet': 1998}, 'bike3': {'hero': 1986}}

# %%
print(a["bike1"])
print(a["bike1"]["ninja"])
# Out:
# {'ninja': 1991}
# 1991
